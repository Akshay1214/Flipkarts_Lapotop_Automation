# %%
from selenium import webdriver
import time
import openpyxl

search_item = input("Enter Your Product:- ")

driver = webdriver.Chrome()
driver.get("https://www.flipkart.com")

try:
    driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]').click()
except:
    pass

driver.find_element_by_xpath('//input[@name="q"]').send_keys(search_item)
driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()


time.sleep(3)

pcontainer = driver.find_element_by_xpath('//div[@class="_1YokD2 _2GoDe3"]')
container = pcontainer.find_elements_by_xpath('//div[@class="_2kHMtA"]')[1]


all_products = container.find_elements_by_xpath('//div[@class="_13oc-S"]')

for product in all_products:
    product.click()
    driver.switch_to.window(driver.window_handles[1])

    try:
        title = driver.find_element_by_xpath('//span[@class="B_NuCI"]').text
        price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]').text
    except:
        pass

    try:
        mrp = driver.find_element_by_xpath('//div[@class="_3I9_wc _2p6lqe"]').text
        discount = driver.find_element_by_xpath('//div[@class="_3Ay6Sb _31Dcoz"]').text
        seller_name = driver.find_element_by_id("sellerName").text
    except:
        pass

    print(f"Title: - {title}")
    print(f"Price:- {price}")
    try:
        print(f"MRP: - {mrp}")
        print(f"Discount:- {discount}")
        print(f"SellerName:- {seller_name}")
    except:
        pass  

    driver.close()
    driver.switch_to.window(driver.window_handles[0])
driver.quit()
# Out:
# Enter Your Product:- laptops
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:12: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]').click()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//input[@name="q"]').send_keys(search_item)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:17: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:22: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   pcontainer = driver.find_element_by_xpath('//div[@class="_1YokD2 _2GoDe3"]')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:23: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   container = pcontainer.find_elements_by_xpath('//div[@class="_2kHMtA"]')[1]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:26: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   all_products = container.find_elements_by_xpath('//div[@class="_13oc-S"]')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   title = driver.find_element_by_xpath('//span[@class="B_NuCI"]').text
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:34: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]').text
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:39: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   mrp = driver.find_element_by_xpath('//div[@class="_3I9_wc _2p6lqe"]').text
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:40: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   discount = driver.find_element_by_xpath('//div[@class="_3Ay6Sb _31Dcoz"]').text
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3944\3705827328.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   seller_name = driver.find_element_by_id("sellerName").text
# Title: - Infinix INBook X1 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) XL11 Thin and Light Laptop  (14 inch, Noble Red, 1.48 kg)
# Price:- ₹39,990
# MRP: - ₹59,999
# Discount:- 33% off
# SellerName:- BUZZINDIA4.7
# Title: - Infinix INBook X1 Pro Core i7 10th Gen - (16 GB/512 GB SSD/Windows 11 Home) XL12 Thin and Light Laptop  (14 Inch, Starfall Grey, 1.48 kg)
# Price:- ₹50,990
# MRP: - ₹74,999
# Discount:- 32% off
# SellerName:- BUZZINDIA4.7
# Title: - Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop  (15.6 Inch, Platinum Grey, 2.38 kg, With MS Office)
# Price:- ₹34,990
# MRP: - ₹56,590
# Discount:- 38% off
# SellerName:- PETILANTE Online4.6
# Title: - HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2629TU Thin and Light Laptop  (15.6 inch, Natural Silver, 1.69 KG, With MS Office)
# Price:- ₹41,990
# MRP: - ₹54,051
# Discount:- 22% off
# SellerName:- PETILANTE Online4.6
# Title: - ASUS VivoBook 15 (2022) Celeron Quad Core - (4 GB/256 GB SSD/Windows 11 Home) X515MA-BR011W Thin and Light Laptop  (15.6 inch, Transparent Silver, 1.80 kg)
# Price:- ₹26,990
# MRP: - ₹33,990
# Discount:- 20% off
# SellerName:- TBL Online4.6
# Title: - ASUS Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) X515EA-EJ312WS Thin and Light Laptop  (15.6 inch, Transparent Silver, 1.80 kg, With MS Office)
# Price:- ₹37,990
# MRP: - ₹52,990
# Discount:- 28% off
# SellerName:- TBL Online4.6
# Title: - HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 10 Home) 15s-GY0501AU Thin and Light Laptop  (15.6 inch, Natural Silver, 1.69 kg, With MS Office)
# Price:- ₹34,990
# MRP: - ₹46,055
# Discount:- 24% off
# SellerName:- IndiFlashMart4.5
# Title: - DELL Inspiron Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) INSPIRON 5410 2 in 1 Laptop  (14 inch, Platinum Silver, 1.5 kg, With MS Office)
# Price:- ₹46,990
# MRP: - ₹68,658
# Discount:- 31% off
# SellerName:- PETILANTE Online4.6
# Title: - Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop  (15.6 inch, Platinum Grey, 1.7 Kg, With MS Office)
# Price:- ₹38,490
# MRP: - ₹62,190
# Discount:- 38% off
# SellerName:- PETILANTE Online4.6
# Title: - Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14IML05 Thin and Light Laptop  (14 inch, Platinum Grey, With MS Office)
# Price:- ₹34,990
# MRP: - ₹57,990
# Discount:- 39% off
# SellerName:- PETILANTE Online4.6
# Title: - ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and Light Laptop  (15.6 inch, Transparent Silver, 1.80 kg, With MS Office)
# Price:- ₹38,990
# MRP: - ₹50,990
# Discount:- 23% off
# SellerName:- TBL Online4.6
# Title: - Infinix X1 Series Core i7 10th Gen - (16 GB/512 GB SSD/Windows 11 Home/128 MB Graphics) XL12 Thin and Light Laptop  (14 Inch, Noble Red, 1.48 kg)
# Price:- ₹50,990
# MRP: - ₹69,999
# Discount:- 27% off
# SellerName:- RetailNet4.6
# Title: - ASUS VivoBook 15 (2022) Core i3 10th Gen - (4 GB/512 GB SSD/Windows 11 Home) X515JA-EJ372WS Thin and Light Laptop  (15.6 inch, Transparent Silver, 1.80 kg, With MS Office)
# Price:- ₹34,990
# MRP: - ₹49,990
# Discount:- 30% off
# SellerName:- TBsmart4.6
# Title: - acer Aspire 3 Dual Core 3020e - (4 GB/256 GB SSD/Windows 11 Home) A314-22 Laptop  (14 Inch, Charcoal Black, 1.9 kg)
# Price:- ₹24,990
# MRP: - ₹34,999
# Discount:- 28% off
# SellerName:- CORSECA4.7
# Title: - Infinix INBook X1 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) XL11 Thin and Light Laptop  (14 inch, Noble Red, 1.48 kg)
# Price:- ₹29,990
# MRP: - ₹49,999
# Discount:- 40% off
# SellerName:- BUZZINDIA4.7
# Title: - DELL Ryzen 3 Dual Core 3250U - (8 GB/512 GB SSD/Windows 11 Home) INSPIRON 3515 Thin and Light Laptop  (15.6 inch, Carbon Black, 1.8 kg, With MS Office)
# Price:- ₹40,990
# MRP: - ₹53,774
# Discount:- 23% off
# SellerName:- PETILANTE Online4.6
# Title: - ASUS VivoBook 15 (2022) Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X515EA-EJ332WS Thin and Light Laptop  (15.6 inch, Transparent Silver, 1.80 kg, With MS Office)
# Price:- ₹40,990
# MRP: - ₹54,990
# Discount:- 25% off
# SellerName:- TBL Online4.6
# Title: - Infinix INBook X1 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) XL11 Thin and Light Laptop  (14 inch, Starfall Grey, 1.48 kg)
# Price:- ₹29,990
# MRP: - ₹49,999
# Discount:- 40% off
# SellerName:- BUZZINDIA4.7
# Title: - HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s- dy2506TU Thin and Light Laptop  (14 inch, Natural Silver, 1.46 kg, With MS Office)
# Price:- ₹38,990
# MRP: - ₹48,933
# Discount:- 20% off
# SellerName:- PETILANTE Online4.6
# Title: - DELL Inspiron Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Inspiron 5410 2 in 1 Laptop  (14 Inch, Platinum Silver, 1.50 Kgs, With MS Office)
# Price:- ₹71,990
# MRP: - ₹95,398
# Discount:- 24% off
# SellerName:- PETILANTE Online4.6
# Title: - ASUS VivoBook K15 OLED Ryzen 7 Octa Core 5700U - (16 GB/512 GB SSD/Windows 11 Home) KM513UA-L713WS Thin and Light Laptop  (15.6 Inch, Transparent Silver, 1.80 Kg, With MS Office)
# Price:- ₹64,990
# MRP: - ₹86,990
# Discount:- 25% off
# SellerName:- TBL Online4.6
# Title: - DELL Inspiron Athlon Dual Core 3050U - (8 GB/256 GB SSD/Windows 11 Home) Inspiron 3525 Notebook  (15.6 Inch, Carbon Black, 1.68 Kg, With MS Office)
# Price:- ₹32,999
# MRP: - ₹46,263
# Discount:- 28% off
# SellerName:- PETILANTE Online4.6
# Title: - Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14ITL6 Thin and Light Laptop  (14 Inch, Arctic Grey, With MS Office)
# Price:- ₹42,990
# MRP: - ₹67,690
# Discount:- 36% off
# SellerName:- PETILANTE Online4.6
# Title: - DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3050) G15-5511 Gaming Laptop  (15.6 inch, Dark Shadow Grey, 2.65 kg, With MS Office)
# Price:- ₹69,490
# MRP: - ₹75,826
# Discount:- 8% off
# SellerName:- PETILANTE Online4.6
